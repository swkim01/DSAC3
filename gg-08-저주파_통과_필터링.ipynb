# %% [markdown]
# <h1>저주파 통과 필터링</h1>
# <br>
# 이미지를 부드럽게 처리하는 필터
# <br>
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/swkim01/DSAC3/blob/main/gg-08-저주파_통과_필터링.ipynb"><img src="https://github.com/swkim01/DSAC3/raw/main/colab_logo_32px.png" />구글 코랩에서 실행</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/swkim01/DSAC3/blob/main/gg-08-저주파_통과_필터링.ipynb"><img src="https://github.com/swkim01/DSAC3/raw/main/GitHub-Mark-32px.png" />깃헙에서 소스 보기</a>
#   </td>
# </table>

# %%
pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.4.0.46-cp38-cp38-win_amd64.whl (33.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('./case.jpg')

# %%
kernel = np.ones((5,5), np.float32) / 25
dst = cv2.filter2D(img, -1, kernel)

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('blur')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# <h1>가우시안 필터링(Gaussian Filtering)</h1>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('./case.jpg')

# %%
blur = cv2.GaussianBlur(img,(5,5),0)

# %%
plt.subplot(121),plt.imshow(img), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]),plt.yticks([])
plt.show(0)

# %% [markdown]
# <h1> Median Filtering</h1>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('./case.jpg')

# %%
blur = cv2.medianBlur(img,5)

# %%
plt.subplot(121), plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# <h1>Bilateral Filtering</h1>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('./case.jpg')

# %%
blur = cv2.bilateralFilter(img,9,75,75)

# %%
plt.subplot(121), plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
